# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
import math
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torch.nn.functional as F

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
from torchvision.datasets import ImageFolder
from PIL import Image

# Criar um objeto ImageFolder
dataset = ImageFolder(r"C:\Users\paulo\Área de Trabalho\codigos\python\Untitled Folder\redes_neurais\Dogs\train")

# Obter o caminho para uma imagem específica no dataset
image_path = dataset.imgs[0][0]  # Exemplo: primeira imagem do dataset

# Abrir a imagem usando PIL
image = Image.open(image_path)

# Obter o tamanho da imagem
image_size = image.size
print(image_size)
#necessário resize
# Out:
# (224, 224)

# %%
mean = [0.485, 0.456, 0.406]  # Médias dos canais R, G e B nas imagens do conjunto de treinamento
std = [0.229, 0.224, 0.225]  # Desvios padrão dos canais R, G e B nas imagens do conjunto de treinamento

transforms_treino_1 = torchvision.transforms.Compose([
       torchvision.transforms.ToTensor(),
       torchvision.transforms.Normalize(mean=mean, std=std)  # Normaliza os valores dos canais de cor
])



transforms_treino_2 = torchvision.transforms.Compose([
       torchvision.transforms.ColorJitter(brightness=0.3, contrast=0.25, saturation=0.4, hue=0.12),
       torchvision.transforms.GaussianBlur(kernel_size=(7, 13), sigma=(0.1, 0.2)),
       torchvision.transforms.ToTensor(),
       torchvision.transforms.Normalize(mean=mean, std=std)  # Normaliza os valores dos canais de cor
])

transforms_treino_3 = torchvision.transforms.Compose([
       torchvision.transforms.RandomHorizontalFlip(),
       torchvision.transforms.RandomRotation(30),
       torchvision.transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
       torchvision.transforms.ToTensor(),
       torchvision.transforms.Normalize(mean=mean, std=std)  # Normaliza os valores dos canais de cor
    ])





transforms_validacao = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=mean, std=std)
])

transforms_teste = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=mean, std=std)
])

#batches
batch_size = 48



trainset_1 = torchvision.datasets.ImageFolder(r"C:\Users\paulo\Área de Trabalho\codigos\python\Untitled Folder\redes_neurais\Dogs\train", transform = transforms_treino_1)
trainset_2 = torchvision.datasets.ImageFolder(r"C:\Users\paulo\Área de Trabalho\codigos\python\Untitled Folder\redes_neurais\Dogs\train", transform = transforms_treino_2)
trainset_3 = torchvision.datasets.ImageFolder(r"C:\Users\paulo\Área de Trabalho\codigos\python\Untitled Folder\redes_neurais\Dogs\train", transform = transforms_treino_3)


validset = torchvision.datasets.ImageFolder(r"C:\Users\paulo\Área de Trabalho\codigos\python\Untitled Folder\redes_neurais\Dogs\valid", transform = transforms_validacao)
testset = torchvision.datasets.ImageFolder(r"C:\Users\paulo\Área de Trabalho\codigos\python\Untitled Folder\redes_neurais\Dogs\test", transform = transforms_teste)




# loaders for data
trainloader_1 = torch.utils.data.DataLoader(trainset_1 , batch_size=batch_size , shuffle = True)
trainloader_2 = torch.utils.data.DataLoader(trainset_2 , batch_size=batch_size , shuffle = True)
trainloader_3 = torch.utils.data.DataLoader(trainset_3 , batch_size=batch_size , shuffle = True)


validloader = torch.utils.data.DataLoader(validset , batch_size=batch_size , shuffle = False)
testloader = torch.utils.data.DataLoader(testset  , batch_size=batch_size)

# %%
in_channels, growth_rate = 64, 32
tamanho_bottleneck = [3,5,7,4]
camada_intermediaria = []



## Camada inicial ##
## (BN - Relu - Conv)  + Max pool ##

camada_inicial = nn.Sequential(
    nn.Conv2d(3, 64, kernel_size=(7,7), stride=2, padding=3), # convolucional
    nn.BatchNorm2d(64), #batch normalization
    nn.ReLU(), # relu ativação
    nn.MaxPool2d(kernel_size=(3,3), stride=2, padding=1)) # Max pool

## Bottleneck Block (mini bloco) ~ compõe o bloco denso ##
## (BN - Relu - Conv) + dropout + (BN - Relu - Conv) + dropout ##

def bottleneck(in_channels, out_channels, dropout=0.2):
    k = nn.Sequential(
        nn.BatchNorm2d(in_channels),
        nn.ReLU(),
        nn.Conv2d(in_channels, out_channels, kernel_size=(1,1), padding=0, stride=1),
        nn.Dropout(p=dropout),

        nn.BatchNorm2d(out_channels),
        nn.ReLU(),
        nn.Conv2d(out_channels, out_channels, kernel_size=(3,3), padding=1, stride=1),
        nn.Dropout(p=dropout))
    return k


## Dense Block (Bloco denso) ##
## União de várias Bottleneck Block (mini blocos) ##

class DenseBlock(nn.Module):
    def __init__(self, tamanho, in_channels, growth_rate):
        super().__init__()
        self.net = nn.Sequential()
        for i in range(tamanho):
            self.net.add_module(f'bottleneck_{i+1}', bottleneck(in_channels + i * growth_rate, growth_rate))

    def forward(self, X):
        for SS in self.net:
            Y = SS(X)
            X = torch.cat((X, Y), dim=1)
        return X





## Transition Block (Bloco de transição) ##
## (BN - Relu - Conv) + dropout + Average Pooling

class Transition(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.2):
        super().__init__()

        self.batch_norm = nn.BatchNorm2d(in_channels)

        self.relu = nn.ReLU(inplace=True)

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1,
                               padding=0, bias=False)

        self.dropout = nn.Dropout(p=dropout)

        self.avgpool = nn.AvgPool2d(kernel_size=(2,2), stride = 2)

    def forward(self, x):
        saida = self.conv1(self.relu(self.batch_norm(x)))

        saida = self.dropout(saida)

        saida = self.avgpool(saida)

        return saida

## Camada intermediária ##
## Junção de dense block + transition + dense block ##


for i, tamanho in enumerate(tamanho_bottleneck):
    camada_intermediaria.append(DenseBlock(tamanho, in_channels, growth_rate))

    in_channels += tamanho * growth_rate

    if i != len(tamanho_bottleneck) - 1:
        camada_intermediaria.append(Transition(in_channels, in_channels // 2))
        in_channels = in_channels // 2


## Classification Layer (Camada de classificação) ##
## BN + Relu + Global AVG Pool + Flatten (diminuir a dimensão) + fully connected ##
camada_final = nn.Sequential(
    nn.BatchNorm2d(in_channels),
    nn.ReLU(),
    nn.AdaptiveAvgPool2d((1, 1)),
    nn.Flatten(),
    nn.Linear(in_channels, 70))


## DenseNet ##
## Junção de tomas as camadas anteriores ##

DenseNet = nn.Sequential(
    camada_inicial,
    *camada_intermediaria,
    camada_final)

## Treino
loss_fn = nn.CrossEntropyLoss()

def train(model, optimizer, train_loader):
    model.train()

    batch_loss = 0.0

    for inputs, labels in train_loader:
        # joga pra GPU, meu filho
        inputs, labels = inputs.to(device, non_blocking = True), labels.to(device, non_blocking = True)

        #forward
        y_hat = model(inputs)
        loss = loss_fn(y_hat, labels)

        optimizer.zero_grad()

        loss.backward() #backward
        optimizer.step() #weight updates

        batch_loss += float(loss)

    train_loss = batch_loss / len(train_loader)

    return train_loss

## teste 

def test(model, optimizer, test_loader):
    model.eval()

    batch_correct = 0
    batch_loss = 0.0

    for inputs, labels in test_loader:
        model.eval()
        inputs, labels = inputs.to(device, non_blocking = True), labels.to(device, non_blocking = True)

        #nao calcular os gradientes (estamos testando o modelo)
        with torch.no_grad():
            y_hat = model(inputs)
            loss = loss_fn(y_hat, labels)

        batch_loss += float(loss)
        batch_correct += (torch.argmax(y_hat,1) == labels).float().sum()

    test_loss = batch_loss/len(test_loader)
    test_acc = batch_correct/len(test_loader.dataset)

    return test_loss, test_acc

#funcao que executa tudo

def train_n_epochs(model, optimizer, train_loader, val_loader, test_loader, n_epochs, nome):
    hist_loss_train = []
    hist_loss_validation = []
    best_epoca,best_acc = 0,0
    score_1 = 0

    for epoch in range(n_epochs):
        train_loss = train(model, optimizer, train_loader)
        val_loss, val_acc = test(model, optimizer, val_loader)
        test_loss, test_acc = test(model,optimizer, test_loader)
        
        score = float(val_acc/val_loss)
        
        if score > score_1:
                save_model(model,nome)
                score_1 = score

        hist_loss_train.append(train_loss)
        hist_loss_validation.append(val_loss)

        print(f"Epoch {epoch}: Train Loss: {train_loss:.2f} Validation Loss: {val_loss:.2f} Validation Accuracy: {val_acc:.2f} Test Accuracy: {test_acc:.2f}")
                                   
        if test_acc > best_acc:
              best_epoca = epoch
              best_acc = test_acc
                                   
                                   
    return hist_loss_train, hist_loss_validation,best_epoca,best_acc

def save_model(model, nome):
    torch.save(model.state_dict(), nome)

# %%
model = DenseNet
model = model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
hist_loss_train_1, hist_loss_validation_1,best_epoca_1,best_acc_1 = train_n_epochs(model, optimizer, trainloader_1, validloader, testloader, 120, 'modelo_1_x.pt')
# Out:
# Epoch 0: Train Loss: 3.87 Validation Loss: 3.74 Validation Accuracy: 0.07 Test Accuracy: 0.09
# Epoch 1: Train Loss: 3.49 Validation Loss: 3.59 Validation Accuracy: 0.14 Test Accuracy: 0.16
# Epoch 2: Train Loss: 3.22 Validation Loss: 3.47 Validation Accuracy: 0.15 Test Accuracy: 0.16
# Epoch 3: Train Loss: 2.99 Validation Loss: 3.36 Validation Accuracy: 0.16 Test Accuracy: 0.19
# Epoch 4: Train Loss: 2.81 Validation Loss: 3.29 Validation Accuracy: 0.18 Test Accuracy: 0.20
# Epoch 5: Train Loss: 2.65 Validation Loss: 2.68 Validation Accuracy: 0.30 Test Accuracy: 0.30
# Epoch 6: Train Loss: 2.47 Validation Loss: 3.00 Validation Accuracy: 0.27 Test Accuracy: 0.29
# Epoch 7: Train Loss: 2.32 Validation Loss: 3.75 Validation Accuracy: 0.21 Test Accuracy: 0.23
# Epoch 8: Train Loss: 2.17 Validation Loss: 2.75 Validation Accuracy: 0.32 Test Accuracy: 0.39
# Epoch 9: Train Loss: 2.04 Validation Loss: 2.88 Validation Accuracy: 0.33 Test Accuracy: 0.34
# Epoch 10: Train Loss: 1.90 Validation Loss: 2.28 Validation Accuracy: 0.42 Test Accuracy: 0.44
# Epoch 11: Train Loss: 1.82 Validation Loss: 2.23 Validation Accuracy: 0.46 Test Accuracy: 0.46
# Epoch 12: Train Loss: 1.70 Validation Loss: 2.13 Validation Accuracy: 0.45 Test Accuracy: 0.48
# Epoch 13: Train Loss: 1.60 Validation Loss: 2.14 Validation Accuracy: 0.47 Test Accuracy: 0.48
# Epoch 14: Train Loss: 1.53 Validation Loss: 2.57 Validation Accuracy: 0.40 Test Accuracy: 0.45
# Epoch 15: Train Loss: 1.44 Validation Loss: 2.40 Validation Accuracy: 0.45 Test Accuracy: 0.45
# Epoch 16: Train Loss: 1.37 Validation Loss: 2.37 Validation Accuracy: 0.47 Test Accuracy: 0.48
# Epoch 17: Train Loss: 1.30 Validation Loss: 2.23 Validation Accuracy: 0.48 Test Accuracy: 0.50
# Epoch 18: Train Loss: 1.23 Validation Loss: 1.97 Validation Accuracy: 0.56 Test Accuracy: 0.55
# Epoch 19: Train Loss: 1.17 Validation Loss: 1.81 Validation Accuracy: 0.58 Test Accuracy: 0.59
# Epoch 20: Train Loss: 1.13 Validation Loss: 1.93 Validation Accuracy: 0.56 Test Accuracy: 0.59
# Epoch 21: Train Loss: 1.07 Validation Loss: 2.26 Validation Accuracy: 0.54 Test Accuracy: 0.54
# Epoch 22: Train Loss: 1.03 Validation Loss: 2.07 Validation Accuracy: 0.54 Test Accuracy: 0.59
# Epoch 23: Train Loss: 0.97 Validation Loss: 2.05 Validation Accuracy: 0.55 Test Accuracy: 0.62
# Epoch 24: Train Loss: 0.91 Validation Loss: 2.27 Validation Accuracy: 0.53 Test Accuracy: 0.60
# Epoch 25: Train Loss: 0.87 Validation Loss: 1.93 Validation Accuracy: 0.59 Test Accuracy: 0.60
# Epoch 26: Train Loss: 0.83 Validation Loss: 2.27 Validation Accuracy: 0.57 Test Accuracy: 0.61
# Epoch 27: Train Loss: 0.81 Validation Loss: 1.86 Validation Accuracy: 0.61 Test Accuracy: 0.64
# Epoch 28: Train Loss: 0.76 Validation Loss: 1.74 Validation Accuracy: 0.66 Test Accuracy: 0.67
# Epoch 29: Train Loss: 0.75 Validation Loss: 2.15 Validation Accuracy: 0.61 Test Accuracy: 0.59
# Epoch 30: Train Loss: 0.70 Validation Loss: 1.70 Validation Accuracy: 0.64 Test Accuracy: 0.68
# Epoch 31: Train Loss: 0.67 Validation Loss: 2.48 Validation Accuracy: 0.56 Test Accuracy: 0.55
# Epoch 32: Train Loss: 0.63 Validation Loss: 2.01 Validation Accuracy: 0.63 Test Accuracy: 0.66
# Epoch 33: Train Loss: 0.63 Validation Loss: 1.85 Validation Accuracy: 0.66 Test Accuracy: 0.65
# Epoch 34: Train Loss: 0.61 Validation Loss: 1.95 Validation Accuracy: 0.65 Test Accuracy: 0.64
# Epoch 35: Train Loss: 0.59 Validation Loss: 1.85 Validation Accuracy: 0.67 Test Accuracy: 0.69
# Epoch 36: Train Loss: 0.55 Validation Loss: 1.80 Validation Accuracy: 0.67 Test Accuracy: 0.72
# Epoch 37: Train Loss: 0.54 Validation Loss: 2.23 Validation Accuracy: 0.62 Test Accuracy: 0.65
# Epoch 38: Train Loss: 0.53 Validation Loss: 1.83 Validation Accuracy: 0.66 Test Accuracy: 0.69
# Epoch 39: Train Loss: 0.47 Validation Loss: 2.15 Validation Accuracy: 0.65 Test Accuracy: 0.68
# Epoch 40: Train Loss: 0.49 Validation Loss: 2.24 Validation Accuracy: 0.60 Test Accuracy: 0.63
# Epoch 41: Train Loss: 0.48 Validation Loss: 1.73 Validation Accuracy: 0.70 Test Accuracy: 0.70
# Epoch 42: Train Loss: 0.46 Validation Loss: 1.89 Validation Accuracy: 0.67 Test Accuracy: 0.69
# Epoch 43: Train Loss: 0.42 Validation Loss: 2.03 Validation Accuracy: 0.67 Test Accuracy: 0.69
# Epoch 44: Train Loss: 0.40 Validation Loss: 1.97 Validation Accuracy: 0.68 Test Accuracy: 0.70
# Epoch 45: Train Loss: 0.39 Validation Loss: 1.74 Validation Accuracy: 0.69 Test Accuracy: 0.70
# Epoch 46: Train Loss: 0.39 Validation Loss: 1.98 Validation Accuracy: 0.69 Test Accuracy: 0.73
# Epoch 47: Train Loss: 0.37 Validation Loss: 2.27 Validation Accuracy: 0.63 Test Accuracy: 0.70
# Epoch 48: Train Loss: 0.36 Validation Loss: 1.72 Validation Accuracy: 0.73 Test Accuracy: 0.74
# Epoch 49: Train Loss: 0.39 Validation Loss: 2.08 Validation Accuracy: 0.65 Test Accuracy: 0.71
# Epoch 50: Train Loss: 0.35 Validation Loss: 2.06 Validation Accuracy: 0.69 Test Accuracy: 0.72
# Epoch 51: Train Loss: 0.33 Validation Loss: 2.10 Validation Accuracy: 0.67 Test Accuracy: 0.70
# Epoch 52: Train Loss: 0.33 Validation Loss: 2.12 Validation Accuracy: 0.69 Test Accuracy: 0.70
# Epoch 53: Train Loss: 0.33 Validation Loss: 2.09 Validation Accuracy: 0.67 Test Accuracy: 0.70
# Epoch 54: Train Loss: 0.33 Validation Loss: 2.13 Validation Accuracy: 0.69 Test Accuracy: 0.72
# Epoch 55: Train Loss: 0.32 Validation Loss: 2.88 Validation Accuracy: 0.59 Test Accuracy: 0.65
# Epoch 56: Train Loss: 0.28 Validation Loss: 1.93 Validation Accuracy: 0.71 Test Accuracy: 0.72
# Epoch 57: Train Loss: 0.28 Validation Loss: 1.93 Validation Accuracy: 0.71 Test Accuracy: 0.70
# Epoch 58: Train Loss: 0.27 Validation Loss: 1.91 Validation Accuracy: 0.71 Test Accuracy: 0.74
# Epoch 59: Train Loss: 0.27 Validation Loss: 2.05 Validation Accuracy: 0.70 Test Accuracy: 0.71
# Epoch 60: Train Loss: 0.27 Validation Loss: 2.15 Validation Accuracy: 0.68 Test Accuracy: 0.71
# Epoch 61: Train Loss: 0.29 Validation Loss: 1.99 Validation Accuracy: 0.70 Test Accuracy: 0.73
# Epoch 62: Train Loss: 0.26 Validation Loss: 2.01 Validation Accuracy: 0.73 Test Accuracy: 0.73
# Epoch 63: Train Loss: 0.27 Validation Loss: 1.96 Validation Accuracy: 0.71 Test Accuracy: 0.71
# Epoch 64: Train Loss: 0.22 Validation Loss: 2.02 Validation Accuracy: 0.72 Test Accuracy: 0.72
# Epoch 65: Train Loss: 0.23 Validation Loss: 1.95 Validation Accuracy: 0.70 Test Accuracy: 0.74
# Epoch 66: Train Loss: 0.21 Validation Loss: 1.81 Validation Accuracy: 0.72 Test Accuracy: 0.74
# Epoch 67: Train Loss: 0.23 Validation Loss: 1.95 Validation Accuracy: 0.74 Test Accuracy: 0.74
# Epoch 68: Train Loss: 0.21 Validation Loss: 2.15 Validation Accuracy: 0.71 Test Accuracy: 0.74
# Epoch 69: Train Loss: 0.25 Validation Loss: 1.98 Validation Accuracy: 0.72 Test Accuracy: 0.72
# Epoch 70: Train Loss: 0.25 Validation Loss: 2.08 Validation Accuracy: 0.72 Test Accuracy: 0.75
# Epoch 71: Train Loss: 0.22 Validation Loss: 2.09 Validation Accuracy: 0.71 Test Accuracy: 0.73
# Epoch 72: Train Loss: 0.23 Validation Loss: 2.03 Validation Accuracy: 0.72 Test Accuracy: 0.71
# Epoch 73: Train Loss: 0.18 Validation Loss: 2.12 Validation Accuracy: 0.71 Test Accuracy: 0.72
# Epoch 74: Train Loss: 0.19 Validation Loss: 2.03 Validation Accuracy: 0.72 Test Accuracy: 0.73
# Epoch 75: Train Loss: 0.20 Validation Loss: 2.31 Validation Accuracy: 0.68 Test Accuracy: 0.69
# Epoch 76: Train Loss: 0.19 Validation Loss: 2.31 Validation Accuracy: 0.70 Test Accuracy: 0.73
# Epoch 77: Train Loss: 0.20 Validation Loss: 2.37 Validation Accuracy: 0.70 Test Accuracy: 0.68
# Epoch 78: Train Loss: 0.19 Validation Loss: 2.20 Validation Accuracy: 0.71 Test Accuracy: 0.76
# Epoch 79: Train Loss: 0.19 Validation Loss: 1.91 Validation Accuracy: 0.74 Test Accuracy: 0.75
# Epoch 80: Train Loss: 0.18 Validation Loss: 2.17 Validation Accuracy: 0.72 Test Accuracy: 0.76
# Epoch 81: Train Loss: 0.18 Validation Loss: 1.90 Validation Accuracy: 0.75 Test Accuracy: 0.75
# Epoch 82: Train Loss: 0.18 Validation Loss: 2.21 Validation Accuracy: 0.70 Test Accuracy: 0.74
# Epoch 83: Train Loss: 0.17 Validation Loss: 2.15 Validation Accuracy: 0.72 Test Accuracy: 0.73
# Epoch 84: Train Loss: 0.17 Validation Loss: 2.46 Validation Accuracy: 0.69 Test Accuracy: 0.73
# Epoch 85: Train Loss: 0.17 Validation Loss: 2.19 Validation Accuracy: 0.70 Test Accuracy: 0.72
# Epoch 86: Train Loss: 0.16 Validation Loss: 2.39 Validation Accuracy: 0.71 Test Accuracy: 0.71
# Epoch 87: Train Loss: 0.16 Validation Loss: 2.13 Validation Accuracy: 0.74 Test Accuracy: 0.75
# Epoch 88: Train Loss: 0.15 Validation Loss: 2.08 Validation Accuracy: 0.73 Test Accuracy: 0.75
# Epoch 89: Train Loss: 0.16 Validation Loss: 2.35 Validation Accuracy: 0.71 Test Accuracy: 0.72
# Epoch 90: Train Loss: 0.16 Validation Loss: 2.49 Validation Accuracy: 0.69 Test Accuracy: 0.73
# Epoch 91: Train Loss: 0.16 Validation Loss: 2.17 Validation Accuracy: 0.74 Test Accuracy: 0.77
# Epoch 92: Train Loss: 0.14 Validation Loss: 2.15 Validation Accuracy: 0.73 Test Accuracy: 0.75
# Epoch 93: Train Loss: 0.16 Validation Loss: 2.24 Validation Accuracy: 0.72 Test Accuracy: 0.73
# Epoch 94: Train Loss: 0.15 Validation Loss: 2.50 Validation Accuracy: 0.69 Test Accuracy: 0.70
# Epoch 95: Train Loss: 0.16 Validation Loss: 2.35 Validation Accuracy: 0.70 Test Accuracy: 0.76
# Epoch 96: Train Loss: 0.14 Validation Loss: 2.25 Validation Accuracy: 0.74 Test Accuracy: 0.72
# Epoch 97: Train Loss: 0.16 Validation Loss: 2.27 Validation Accuracy: 0.71 Test Accuracy: 0.72
# Epoch 98: Train Loss: 0.14 Validation Loss: 2.16 Validation Accuracy: 0.74 Test Accuracy: 0.77
# Epoch 99: Train Loss: 0.15 Validation Loss: 2.31 Validation Accuracy: 0.71 Test Accuracy: 0.76
# Epoch 100: Train Loss: 0.15 Validation Loss: 2.26 Validation Accuracy: 0.73 Test Accuracy: 0.75
# Epoch 101: Train Loss: 0.11 Validation Loss: 2.17 Validation Accuracy: 0.75 Test Accuracy: 0.78
# Epoch 102: Train Loss: 0.13 Validation Loss: 2.24 Validation Accuracy: 0.73 Test Accuracy: 0.74
# Epoch 103: Train Loss: 0.14 Validation Loss: 2.22 Validation Accuracy: 0.74 Test Accuracy: 0.75
# Epoch 104: Train Loss: 0.13 Validation Loss: 2.29 Validation Accuracy: 0.73 Test Accuracy: 0.75
# Epoch 105: Train Loss: 0.14 Validation Loss: 2.34 Validation Accuracy: 0.71 Test Accuracy: 0.76
# Epoch 106: Train Loss: 0.12 Validation Loss: 2.41 Validation Accuracy: 0.72 Test Accuracy: 0.76
# Epoch 107: Train Loss: 0.11 Validation Loss: 2.26 Validation Accuracy: 0.73 Test Accuracy: 0.77
# Epoch 108: Train Loss: 0.11 Validation Loss: 2.27 Validation Accuracy: 0.74 Test Accuracy: 0.76
# Epoch 109: Train Loss: 0.14 Validation Loss: 2.49 Validation Accuracy: 0.70 Test Accuracy: 0.75
# Epoch 110: Train Loss: 0.14 Validation Loss: 2.24 Validation Accuracy: 0.75 Test Accuracy: 0.77
# Epoch 111: Train Loss: 0.13 Validation Loss: 2.39 Validation Accuracy: 0.72 Test Accuracy: 0.73
# Epoch 112: Train Loss: 0.13 Validation Loss: 2.32 Validation Accuracy: 0.73 Test Accuracy: 0.74
# Epoch 113: Train Loss: 0.14 Validation Loss: 2.58 Validation Accuracy: 0.71 Test Accuracy: 0.73
# Epoch 114: Train Loss: 0.13 Validation Loss: 2.45 Validation Accuracy: 0.72 Test Accuracy: 0.76
# Epoch 115: Train Loss: 0.12 Validation Loss: 2.38 Validation Accuracy: 0.73 Test Accuracy: 0.75
# Epoch 116: Train Loss: 0.12 Validation Loss: 2.29 Validation Accuracy: 0.73 Test Accuracy: 0.75
# Epoch 117: Train Loss: 0.11 Validation Loss: 2.49 Validation Accuracy: 0.72 Test Accuracy: 0.75
# Epoch 118: Train Loss: 0.12 Validation Loss: 2.81 Validation Accuracy: 0.68 Test Accuracy: 0.72
# Epoch 119: Train Loss: 0.09 Validation Loss: 2.51 Validation Accuracy: 0.72 Test Accuracy: 0.74

# %%
model.load_state_dict(torch.load('modelo_1_x.pt'))
model = model.to(device)

hist_loss_train_2, hist_loss_validation_2,best_epoca_2,best_acc_2 = train_n_epochs(model, optimizer, trainloader_2, validloader, testloader, 120, 'modelo_2_x.pt')
# Out:
# Epoch 0: Train Loss: 1.19 Validation Loss: 1.90 Validation Accuracy: 0.64 Test Accuracy: 0.65
# Epoch 1: Train Loss: 0.88 Validation Loss: 1.87 Validation Accuracy: 0.66 Test Accuracy: 0.68
# Epoch 2: Train Loss: 0.74 Validation Loss: 1.78 Validation Accuracy: 0.66 Test Accuracy: 0.68
# Epoch 3: Train Loss: 0.68 Validation Loss: 2.73 Validation Accuracy: 0.56 Test Accuracy: 0.58
# Epoch 4: Train Loss: 0.63 Validation Loss: 1.83 Validation Accuracy: 0.70 Test Accuracy: 0.70
# Epoch 5: Train Loss: 0.59 Validation Loss: 1.83 Validation Accuracy: 0.68 Test Accuracy: 0.71
# Epoch 6: Train Loss: 0.56 Validation Loss: 1.69 Validation Accuracy: 0.70 Test Accuracy: 0.73
# Epoch 7: Train Loss: 0.54 Validation Loss: 1.81 Validation Accuracy: 0.69 Test Accuracy: 0.72
# Epoch 8: Train Loss: 0.54 Validation Loss: 1.65 Validation Accuracy: 0.73 Test Accuracy: 0.77
# Epoch 9: Train Loss: 0.51 Validation Loss: 1.93 Validation Accuracy: 0.68 Test Accuracy: 0.70
# Epoch 10: Train Loss: 0.49 Validation Loss: 1.78 Validation Accuracy: 0.72 Test Accuracy: 0.72
# Epoch 11: Train Loss: 0.47 Validation Loss: 1.70 Validation Accuracy: 0.72 Test Accuracy: 0.71
# Epoch 12: Train Loss: 0.50 Validation Loss: 1.81 Validation Accuracy: 0.71 Test Accuracy: 0.72
# Epoch 13: Train Loss: 0.44 Validation Loss: 1.78 Validation Accuracy: 0.73 Test Accuracy: 0.73
# Epoch 14: Train Loss: 0.43 Validation Loss: 1.60 Validation Accuracy: 0.73 Test Accuracy: 0.76
# Epoch 15: Train Loss: 0.41 Validation Loss: 1.81 Validation Accuracy: 0.68 Test Accuracy: 0.73
# Epoch 16: Train Loss: 0.39 Validation Loss: 1.62 Validation Accuracy: 0.74 Test Accuracy: 0.73
# Epoch 17: Train Loss: 0.41 Validation Loss: 1.60 Validation Accuracy: 0.75 Test Accuracy: 0.78
# Epoch 18: Train Loss: 0.42 Validation Loss: 1.86 Validation Accuracy: 0.74 Test Accuracy: 0.73
# Epoch 19: Train Loss: 0.39 Validation Loss: 1.82 Validation Accuracy: 0.74 Test Accuracy: 0.75
# Epoch 20: Train Loss: 0.41 Validation Loss: 1.75 Validation Accuracy: 0.72 Test Accuracy: 0.73
# Epoch 21: Train Loss: 0.37 Validation Loss: 1.63 Validation Accuracy: 0.73 Test Accuracy: 0.76
# Epoch 22: Train Loss: 0.36 Validation Loss: 1.77 Validation Accuracy: 0.70 Test Accuracy: 0.73
# Epoch 23: Train Loss: 0.34 Validation Loss: 1.75 Validation Accuracy: 0.74 Test Accuracy: 0.73
# Epoch 24: Train Loss: 0.35 Validation Loss: 1.72 Validation Accuracy: 0.74 Test Accuracy: 0.76
# Epoch 25: Train Loss: 0.33 Validation Loss: 1.73 Validation Accuracy: 0.73 Test Accuracy: 0.76
# Epoch 26: Train Loss: 0.33 Validation Loss: 1.80 Validation Accuracy: 0.74 Test Accuracy: 0.75
# Epoch 27: Train Loss: 0.32 Validation Loss: 1.94 Validation Accuracy: 0.70 Test Accuracy: 0.71
# Epoch 28: Train Loss: 0.34 Validation Loss: 1.82 Validation Accuracy: 0.74 Test Accuracy: 0.76
# Epoch 29: Train Loss: 0.33 Validation Loss: 1.74 Validation Accuracy: 0.75 Test Accuracy: 0.75
# Epoch 30: Train Loss: 0.31 Validation Loss: 2.10 Validation Accuracy: 0.72 Test Accuracy: 0.73
# Epoch 31: Train Loss: 0.33 Validation Loss: 1.70 Validation Accuracy: 0.76 Test Accuracy: 0.79
# Epoch 32: Train Loss: 0.32 Validation Loss: 1.88 Validation Accuracy: 0.75 Test Accuracy: 0.76
# Epoch 33: Train Loss: 0.30 Validation Loss: 1.72 Validation Accuracy: 0.76 Test Accuracy: 0.76
# Epoch 34: Train Loss: 0.28 Validation Loss: 1.92 Validation Accuracy: 0.75 Test Accuracy: 0.77
# Epoch 35: Train Loss: 0.29 Validation Loss: 1.70 Validation Accuracy: 0.75 Test Accuracy: 0.78
# Epoch 36: Train Loss: 0.26 Validation Loss: 1.79 Validation Accuracy: 0.76 Test Accuracy: 0.75
# Epoch 37: Train Loss: 0.28 Validation Loss: 2.04 Validation Accuracy: 0.71 Test Accuracy: 0.72
# Epoch 38: Train Loss: 0.29 Validation Loss: 1.75 Validation Accuracy: 0.74 Test Accuracy: 0.75
# Epoch 39: Train Loss: 0.29 Validation Loss: 1.97 Validation Accuracy: 0.72 Test Accuracy: 0.75
# Epoch 40: Train Loss: 0.27 Validation Loss: 1.67 Validation Accuracy: 0.77 Test Accuracy: 0.76
# Epoch 41: Train Loss: 0.27 Validation Loss: 1.74 Validation Accuracy: 0.75 Test Accuracy: 0.75
# Epoch 42: Train Loss: 0.26 Validation Loss: 1.83 Validation Accuracy: 0.76 Test Accuracy: 0.76
# Epoch 43: Train Loss: 0.27 Validation Loss: 1.69 Validation Accuracy: 0.78 Test Accuracy: 0.75
# Epoch 44: Train Loss: 0.26 Validation Loss: 1.96 Validation Accuracy: 0.72 Test Accuracy: 0.75
# Epoch 45: Train Loss: 0.27 Validation Loss: 1.80 Validation Accuracy: 0.77 Test Accuracy: 0.77
# Epoch 46: Train Loss: 0.24 Validation Loss: 1.80 Validation Accuracy: 0.77 Test Accuracy: 0.79
# Epoch 47: Train Loss: 0.25 Validation Loss: 1.75 Validation Accuracy: 0.78 Test Accuracy: 0.78
# Epoch 48: Train Loss: 0.23 Validation Loss: 1.78 Validation Accuracy: 0.76 Test Accuracy: 0.79
# Epoch 49: Train Loss: 0.24 Validation Loss: 2.05 Validation Accuracy: 0.75 Test Accuracy: 0.78
# Epoch 50: Train Loss: 0.24 Validation Loss: 2.09 Validation Accuracy: 0.74 Test Accuracy: 0.74
# Epoch 51: Train Loss: 0.22 Validation Loss: 2.10 Validation Accuracy: 0.73 Test Accuracy: 0.73
# Epoch 52: Train Loss: 0.21 Validation Loss: 1.58 Validation Accuracy: 0.79 Test Accuracy: 0.81
# Epoch 53: Train Loss: 0.21 Validation Loss: 1.70 Validation Accuracy: 0.78 Test Accuracy: 0.79
# Epoch 54: Train Loss: 0.21 Validation Loss: 2.00 Validation Accuracy: 0.75 Test Accuracy: 0.76
# Epoch 55: Train Loss: 0.22 Validation Loss: 1.89 Validation Accuracy: 0.76 Test Accuracy: 0.76
# Epoch 56: Train Loss: 0.22 Validation Loss: 2.15 Validation Accuracy: 0.76 Test Accuracy: 0.76
# Epoch 57: Train Loss: 0.22 Validation Loss: 2.08 Validation Accuracy: 0.75 Test Accuracy: 0.76
# Epoch 58: Train Loss: 0.19 Validation Loss: 2.01 Validation Accuracy: 0.78 Test Accuracy: 0.77
# Epoch 59: Train Loss: 0.23 Validation Loss: 1.77 Validation Accuracy: 0.76 Test Accuracy: 0.80
# Epoch 60: Train Loss: 0.22 Validation Loss: 2.09 Validation Accuracy: 0.73 Test Accuracy: 0.74
# Epoch 61: Train Loss: 0.21 Validation Loss: 1.86 Validation Accuracy: 0.75 Test Accuracy: 0.76
# Epoch 62: Train Loss: 0.20 Validation Loss: 2.02 Validation Accuracy: 0.76 Test Accuracy: 0.76
# Epoch 63: Train Loss: 0.18 Validation Loss: 2.08 Validation Accuracy: 0.74 Test Accuracy: 0.76
# Epoch 64: Train Loss: 0.19 Validation Loss: 1.95 Validation Accuracy: 0.77 Test Accuracy: 0.78
# Epoch 65: Train Loss: 0.19 Validation Loss: 1.80 Validation Accuracy: 0.77 Test Accuracy: 0.74
# Epoch 66: Train Loss: 0.19 Validation Loss: 1.84 Validation Accuracy: 0.76 Test Accuracy: 0.78
# Epoch 67: Train Loss: 0.20 Validation Loss: 2.15 Validation Accuracy: 0.73 Test Accuracy: 0.75
# Epoch 68: Train Loss: 0.21 Validation Loss: 2.25 Validation Accuracy: 0.72 Test Accuracy: 0.75
# Epoch 69: Train Loss: 0.19 Validation Loss: 1.82 Validation Accuracy: 0.77 Test Accuracy: 0.77
# Epoch 70: Train Loss: 0.18 Validation Loss: 1.92 Validation Accuracy: 0.77 Test Accuracy: 0.78
# Epoch 71: Train Loss: 0.20 Validation Loss: 1.82 Validation Accuracy: 0.80 Test Accuracy: 0.79
# Epoch 72: Train Loss: 0.19 Validation Loss: 1.93 Validation Accuracy: 0.76 Test Accuracy: 0.77
# Epoch 73: Train Loss: 0.20 Validation Loss: 1.90 Validation Accuracy: 0.78 Test Accuracy: 0.80
# Epoch 74: Train Loss: 0.16 Validation Loss: 1.94 Validation Accuracy: 0.76 Test Accuracy: 0.77
# Epoch 75: Train Loss: 0.17 Validation Loss: 1.95 Validation Accuracy: 0.77 Test Accuracy: 0.77
# Epoch 76: Train Loss: 0.18 Validation Loss: 1.85 Validation Accuracy: 0.79 Test Accuracy: 0.79
# Epoch 77: Train Loss: 0.17 Validation Loss: 1.83 Validation Accuracy: 0.79 Test Accuracy: 0.81
# Epoch 78: Train Loss: 0.16 Validation Loss: 2.22 Validation Accuracy: 0.76 Test Accuracy: 0.78
# Epoch 79: Train Loss: 0.17 Validation Loss: 1.92 Validation Accuracy: 0.78 Test Accuracy: 0.80
# Epoch 80: Train Loss: 0.16 Validation Loss: 2.11 Validation Accuracy: 0.76 Test Accuracy: 0.80
# Epoch 81: Train Loss: 0.15 Validation Loss: 2.02 Validation Accuracy: 0.77 Test Accuracy: 0.79
# Epoch 82: Train Loss: 0.16 Validation Loss: 1.99 Validation Accuracy: 0.78 Test Accuracy: 0.78
# Epoch 83: Train Loss: 0.17 Validation Loss: 2.09 Validation Accuracy: 0.75 Test Accuracy: 0.78
# Epoch 84: Train Loss: 0.16 Validation Loss: 1.76 Validation Accuracy: 0.79 Test Accuracy: 0.79
# Epoch 85: Train Loss: 0.16 Validation Loss: 2.19 Validation Accuracy: 0.76 Test Accuracy: 0.77
# Epoch 86: Train Loss: 0.16 Validation Loss: 1.92 Validation Accuracy: 0.78 Test Accuracy: 0.78
# Epoch 87: Train Loss: 0.16 Validation Loss: 2.14 Validation Accuracy: 0.76 Test Accuracy: 0.79
# Epoch 88: Train Loss: 0.15 Validation Loss: 2.07 Validation Accuracy: 0.76 Test Accuracy: 0.80
# Epoch 89: Train Loss: 0.16 Validation Loss: 1.95 Validation Accuracy: 0.78 Test Accuracy: 0.80
# Epoch 90: Train Loss: 0.14 Validation Loss: 2.10 Validation Accuracy: 0.77 Test Accuracy: 0.76
# Epoch 91: Train Loss: 0.15 Validation Loss: 2.09 Validation Accuracy: 0.74 Test Accuracy: 0.77
# Epoch 92: Train Loss: 0.15 Validation Loss: 2.03 Validation Accuracy: 0.77 Test Accuracy: 0.79
# Epoch 93: Train Loss: 0.14 Validation Loss: 1.67 Validation Accuracy: 0.80 Test Accuracy: 0.81
# Epoch 94: Train Loss: 0.15 Validation Loss: 2.25 Validation Accuracy: 0.75 Test Accuracy: 0.79
# Epoch 95: Train Loss: 0.14 Validation Loss: 2.08 Validation Accuracy: 0.77 Test Accuracy: 0.78
# Epoch 96: Train Loss: 0.14 Validation Loss: 2.35 Validation Accuracy: 0.76 Test Accuracy: 0.77
# Epoch 97: Train Loss: 0.14 Validation Loss: 2.04 Validation Accuracy: 0.77 Test Accuracy: 0.80
# Epoch 98: Train Loss: 0.16 Validation Loss: 2.06 Validation Accuracy: 0.78 Test Accuracy: 0.79
# Epoch 99: Train Loss: 0.15 Validation Loss: 2.21 Validation Accuracy: 0.77 Test Accuracy: 0.78
# Epoch 100: Train Loss: 0.15 Validation Loss: 2.17 Validation Accuracy: 0.76 Test Accuracy: 0.78
# Epoch 101: Train Loss: 0.14 Validation Loss: 2.22 Validation Accuracy: 0.78 Test Accuracy: 0.79
# Epoch 102: Train Loss: 0.14 Validation Loss: 2.07 Validation Accuracy: 0.75 Test Accuracy: 0.77
# Epoch 103: Train Loss: 0.16 Validation Loss: 2.13 Validation Accuracy: 0.78 Test Accuracy: 0.79
# Epoch 104: Train Loss: 0.13 Validation Loss: 2.01 Validation Accuracy: 0.78 Test Accuracy: 0.81
# Epoch 105: Train Loss: 0.13 Validation Loss: 2.18 Validation Accuracy: 0.76 Test Accuracy: 0.79
# Epoch 106: Train Loss: 0.14 Validation Loss: 2.10 Validation Accuracy: 0.77 Test Accuracy: 0.78
# Epoch 107: Train Loss: 0.13 Validation Loss: 2.14 Validation Accuracy: 0.76 Test Accuracy: 0.79
# Epoch 108: Train Loss: 0.14 Validation Loss: 2.17 Validation Accuracy: 0.76 Test Accuracy: 0.78
# Epoch 109: Train Loss: 0.13 Validation Loss: 1.92 Validation Accuracy: 0.79 Test Accuracy: 0.82
# Epoch 110: Train Loss: 0.13 Validation Loss: 2.03 Validation Accuracy: 0.79 Test Accuracy: 0.79
# Epoch 111: Train Loss: 0.14 Validation Loss: 2.13 Validation Accuracy: 0.78 Test Accuracy: 0.81
# Epoch 112: Train Loss: 0.13 Validation Loss: 1.95 Validation Accuracy: 0.79 Test Accuracy: 0.79
# Epoch 113: Train Loss: 0.11 Validation Loss: 2.20 Validation Accuracy: 0.77 Test Accuracy: 0.76
# Epoch 114: Train Loss: 0.13 Validation Loss: 2.19 Validation Accuracy: 0.77 Test Accuracy: 0.79
# Epoch 115: Train Loss: 0.13 Validation Loss: 2.06 Validation Accuracy: 0.76 Test Accuracy: 0.77
# Epoch 116: Train Loss: 0.13 Validation Loss: 2.05 Validation Accuracy: 0.77 Test Accuracy: 0.78
# Epoch 117: Train Loss: 0.13 Validation Loss: 2.08 Validation Accuracy: 0.77 Test Accuracy: 0.81
# Epoch 118: Train Loss: 0.15 Validation Loss: 2.14 Validation Accuracy: 0.78 Test Accuracy: 0.80
# Epoch 119: Train Loss: 0.11 Validation Loss: 2.04 Validation Accuracy: 0.79 Test Accuracy: 0.80

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
model = DenseNet
model = model.to(device)
model.load_state_dict(torch.load('modelo_2_x.pt'))
model = model.to(device)
class_names = testset.classes

def evaluate_model(model, dataloader, device, class_names):
    model.eval()
    predictions = []
    targets = []

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            probabilities = F.softmax(outputs, dim=1)
            _, preds = torch.max(probabilities, dim=1)

            predictions.extend(preds.cpu().tolist())
            targets.extend(labels.cpu().tolist())

    accuracy = accuracy_score(targets, predictions)
    confusion = confusion_matrix(targets, predictions)
    report = classification_report(targets, predictions, target_names=class_names)
    
    return accuracy, confusion, report


# Supondo que você tenha a lista 'class_names' com os nomes das classes na ordem correta

accuracy, confusion, report = evaluate_model(model, testloader, device, class_names)

print(report)
# Out:
#                    precision    recall  f1-score   support
#
#            Afghan       0.75      0.90      0.82        10
#  African Wild Dog       1.00      1.00      1.00        10
#          Airedale       0.80      0.80      0.80        10
# American Hairless       1.00      0.60      0.75        10
#  American Spaniel       0.64      0.70      0.67        10
#           Basenji       0.56      0.90      0.69        10
#            Basset       0.75      0.90      0.82        10
#            Beagle       1.00      0.90      0.95        10
#    Bearded Collie       1.00      0.70      0.82        10
#          Bermaise       0.91      1.00      0.95        10
#      Bichon Frise       1.00      0.90      0.95        10
#          Blenheim       0.69      0.90      0.78        10
#        Bloodhound       1.00      1.00      1.00        10
#          Bluetick       0.89      0.80      0.84        10
#     Border Collie       1.00      0.40      0.57        10
#            Borzoi       0.90      0.90      0.90        10
#    Boston Terrier       0.73      0.80      0.76        10
#             Boxer       0.83      1.00      0.91        10
#      Bull Mastiff       0.67      0.60      0.63        10
#      Bull Terrier       0.90      0.90      0.90        10
#           Bulldog       0.88      0.70      0.78        10
#             Cairn       0.62      0.80      0.70        10
#         Chihuahua       1.00      0.60      0.75        10
#   Chinese Crested       1.00      0.70      0.82        10
#              Chow       0.89      0.80      0.84        10
#           Clumber       0.69      0.90      0.78        10
#          Cockapoo       0.77      1.00      0.87        10
#            Cocker       0.50      0.30      0.37        10
#            Collie       0.67      0.60      0.63        10
#             Corgi       0.88      0.70      0.78        10
#            Coyote       1.00      0.70      0.82        10
#         Dalmation       0.83      1.00      0.91        10
#             Dhole       1.00      0.60      0.75        10
#             Dingo       0.50      0.70      0.58        10
#          Doberman       0.82      0.90      0.86        10
#         Elk Hound       0.80      0.80      0.80        10
#    French Bulldog       0.88      0.70      0.78        10
#    German Sheperd       0.73      0.80      0.76        10
#  Golden Retriever       0.73      0.80      0.76        10
#        Great Dane       0.75      0.60      0.67        10
#    Great Perenees       0.80      0.80      0.80        10
#         Greyhound       0.86      0.60      0.71        10
#       Groenendael       0.75      0.90      0.82        10
#     Irish Spaniel       0.78      0.70      0.74        10
#   Irish Wolfhound       0.83      1.00      0.91        10
#  Japanese Spaniel       0.69      0.90      0.78        10
#          Komondor       0.83      1.00      0.91        10
#       Labradoodle       1.00      0.70      0.82        10
#          Labrador       0.62      1.00      0.77        10
#             Lhasa       0.77      1.00      0.87        10
#          Malinois       1.00      0.60      0.75        10
#           Maltese       0.89      0.80      0.84        10
#      Mex Hairless       0.71      1.00      0.83        10
#      Newfoundland       0.88      0.70      0.78        10
#          Pekinese       0.90      0.90      0.90        10
#          Pit Bull       0.90      0.90      0.90        10
#        Pomeranian       0.83      1.00      0.91        10
#            Poodle       0.53      0.90      0.67        10
#               Pug       0.86      0.60      0.71        10
#         Rhodesian       0.69      0.90      0.78        10
#        Rottweiler       0.70      0.70      0.70        10
#     Saint Bernard       0.78      0.70      0.74        10
#         Schnauzer       1.00      0.90      0.95        10
#    Scotch Terrier       0.88      0.70      0.78        10
#          Shar_Pei       1.00      1.00      1.00        10
#         Shiba Inu       0.90      0.90      0.90        10
#          Shih-Tzu       1.00      0.70      0.82        10
#    Siberian Husky       0.91      1.00      0.95        10
#            Vizsla       0.83      1.00      0.91        10
#            Yorkie       1.00      0.60      0.75        10
#
#          accuracy                           0.81       700
#         macro avg       0.83      0.81      0.80       700
#      weighted avg       0.83      0.81      0.80       700
